# %%
#Importing Libraries

import numpy as np #To handle Mathematical calculations
import matplotlib.pyplot as plt #To plot charts 
# %matplotlib inline
import pandas as pd #To import and manage datasets
import glob
import os
import warnings
# pd.set_option('display.max_columns', None)  
# pd.set_option('display.max_rows', None)  

#Disable warning messages
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Load preprocessed dataset
combinedPlayerDataframe = pd.read_csv("Preprocessed Player Data.csv")

# %%
combinedPlayerDataframe.head()
# Out:
#                  Name              Team  Age Position  Apps  Minutes  \
# 0        Arjen Robben     Bayern Munich   26        M    18     1779
# 1     Stefan Kießling  Bayer Leverkusen   26       FW    33     2924
# 2  Zvjezdan Misimovic         Wolfsburg   28       AM    31     2768
# 3          Edin Dzeko         Wolfsburg   24       FW    33     3003
# 4     Claudio Pizarro     Werder Bremen   31       AM    23     2130
#
#    Total goals  Total Assists  Shots per game  Key passes per game  ...  \
# 0           16              6             3.4                  1.8  ...
# 1           21              5             3.0                  1.6  ...
# 2           10             13             2.4                  3.3  ...
# 3           22              7             4.5                  1.1  ...
# 4           16              2             2.6                  1.3  ...
#
#    Passes per game  Pass success percentage  Crosses per game  \
# 0             34.3                     80.2               1.5
# 1             32.5                     72.4               0.2
# 2             51.1                     77.5               2.5
# 3             19.5                     70.7               0.2
# 4             24.2                     75.5               0.1
#
#    Long balls per game  Through balls per game  Total Goals Yellow cards  \
# 0                  2.0                     0.2           16            1
# 1                  0.4                     0.1           21            3
# 2                  5.7                     0.5           10            7
# 3                  1.1                     0.1           22            4
# 4                  0.8                     0.0           16            4
#
#    Red cards  Aerials won per game  Man of the match
# 0          0                   0.4                 8
# 1          0                   2.1                 6
# 2          0                   0.2                 8
# 3          0                   0.7                 6
# 4          0                   0.4                 2
#
# [5 rows x 35 columns]

# %%
#Load forecasted rating dataset
forecastedPlayerDataframe = pd.read_csv("Forecasted Ratings 2019-2022.csv")

# %%
forecastedPlayerDataframe.head()
# Out:
#                      Name  Season  Rating  Age      Mean  Growth
# 0            Aaron Hughes    2009    6.95   30  6.880000   -0.20
# 1              Aaron Hunt    2009    7.15   23  7.023750   -0.36
# 2            Aaron Lennon    2009    7.33   23  6.806667   -0.95
# 3           Aaron Mokoena    2009    6.56   29  6.560000    0.00
# 4  Abdelhamid El Kaoutari    2009    6.70   20  6.866667   -0.20

# %%
combinedPlayerDataframe.loc[(combinedPlayerDataframe.Team == 'Bayern Munich') & (combinedPlayerDataframe.Season == 2018) & (combinedPlayerDataframe.Apps > 10)]
# Out:
#                     Name           Team  Age Position  Apps  Minutes  \
# 2524  Robert Lewandowski  Bayern Munich   30       FW    33     2959
# 2525    Thiago Alcántara  Bayern Munich   28        M    26     2409
# 2530      Joshua Kimmich  Bayern Munich   24        D    34     3060
# 2536      Kingsley Coman  Bayern Munich   23       AM    17     1392
# 2547     James Rodríguez  Bayern Munich   27       AM    13     1143
# 2550       Thomas Müller  Bayern Munich   29        M    28     2391
# 2554        Mats Hummels  Bayern Munich   30        D    20     1776
# 2555        Serge Gnabry  Bayern Munich   23       AM    21     1774
# 2574         David Alaba  Bayern Munich   27        D    29     2534
# 2589       Leon Goretzka  Bayern Munich   24        M    23     2021
# 2590         Niklas Süle  Bayern Munich   23        D    29     2652
# 2622       Javi Martínez  Bayern Munich   30        D    16     1313
# 2628      Jérôme Boateng  Bayern Munich   30        D    19     1694
# 2806        Manuel Neuer  Bayern Munich   33       GK    26     2303
#
#       Total goals  Total Assists  Shots per game  Key passes per game  ...  \
# 2524           22              7             4.4                  1.4  ...
# 2525            2              6             0.8                  1.3  ...
# 2530            2             13             0.7                  2.4  ...
# 2536            6              4             1.5                  1.3  ...
# 2547            7              3             1.8                  2.6  ...
# 2550            6              9             2.0                  1.9  ...
# 2554            1              1             0.9                  0.6  ...
# 2555           10              5             2.2                  0.9  ...
# 2574            3              3             1.5                  0.9  ...
# 2589            8              4             1.8                  0.6  ...
# 2590            2              0             0.6                  0.2  ...
# 2622            3              0             0.9                  0.3  ...
# 2628            0              2             0.7                  0.6  ...
# 2806            0              0             0.0                  0.0  ...
#
#       Passes per game  Pass success percentage  Crosses per game  \
# 2524             22.1                     77.5               0.0
# 2525             83.6                     91.8               0.5
# 2530             74.1                     90.5               2.2
# 2536             29.4                     85.0               0.7
# 2547             43.9                     87.1               1.6
# 2550             37.5                     74.7               0.2
# 2554             82.6                     89.4               0.0
# 2555             26.4                     83.4               0.3
# 2574             56.9                     85.5               0.7
# 2589             38.4                     87.5               0.0
# 2590             82.6                     92.9               0.0
# 2622             43.0                     87.8               0.0
# 2628             79.8                     89.0               0.1
# 2806             31.1                     81.6               0.0
#
#       Long balls per game  Through balls per game  Total Goals Yellow cards  \
# 2524                  0.6                     0.2           22            2
# 2525                  7.3                     0.1            2            5
# 2530                  4.2                     0.1            2            4
# 2536                  0.5                     0.0            6            2
# 2547                  2.4                     0.2            7            2
# 2550                  1.2                     0.1            6            1
# 2554                  4.5                     0.1            1            1
# 2555                  1.0                     0.1           10            0
# 2574                  1.7                     0.0            3            4
# 2589                  1.2                     0.0            8            3
# 2590                  5.3                     0.0            2            3
# 2622                  1.9                     0.0            3            3
# 2628                  7.1                     0.2            0            1
# 2806                  5.5                     0.0            0            1
#
#       Red cards  Aerials won per game  Man of the match
# 2524          0                   1.7                 5
# 2525          0                   1.2                 3
# 2530          0                   0.7                 4
# 2536          0                   0.6                 2
# 2547          0                   0.2                 3
# 2550          0                   1.6                 3
# 2554          0                   4.0                 0
# 2555          0                   0.2                 3
# 2574          0                   0.8                 0
# 2589          0                   1.3                 1
# 2590          0                   2.6                 0
# 2622          0                   2.5                 1
# 2628          0                   1.5                 0
# 2806          0                   0.2                 0
#
# [14 rows x 35 columns]
