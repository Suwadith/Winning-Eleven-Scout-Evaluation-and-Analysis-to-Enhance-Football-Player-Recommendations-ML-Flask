# %%
#Importing Libraries
import numpy as np #To handle Mathematical calculations
import matplotlib.pyplot as plt #To plot charts 
# %matplotlib inline
import pandas as pd #TO import and manage datasets
import glob
import os
# pd.set_option('display.max_columns', None)  
# pd.set_option('display.max_rows', None)

# %%
#Combining All Offensive Data
path = r'../Datasets/Whoscored/Player-Stats'
folder = glob.glob(path + "/*Offensive*.csv")

li = []

for file in folder:
    individualOffensivePlayerDataframe = pd.read_csv(file)
    league = os.path.basename(file).split('-')[0]
    season = os.path.basename(file).split('-')[2]
    individualOffensivePlayerDataframe['League'] = league
    individualOffensivePlayerDataframe['Season'] = season
    for index, row in individualOffensivePlayerDataframe.iterrows():
        age = int(row["Age"]) - (2018-int(row["Season"]))
        individualOffensivePlayerDataframe.set_value(index, 'Age', age)
        
        #Cleaning Apps column
        if '(' in row["Apps"] :
            apps = int(row["Apps"].split("(")[0])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
        else :
            apps = int(row["Apps"])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
            
#     individualOffensivePlayerDataframe = individualOffensivePlayerDataframe.drop_duplicates(subset=['Name'], keep='first')
    li.append(individualOffensivePlayerDataframe)

combinedOffensivePlayerDataframe = pd.concat(li)
# Out:
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
#Combining All Defensive Data
path = r'../Datasets/Whoscored/Player-Stats'
folder = glob.glob(path + "/*Defensive*.csv")

li = []

for file in folder:
    individualOffensivePlayerDataframe = pd.read_csv(file)
    league = os.path.basename(file).split('-')[0]
    season = os.path.basename(file).split('-')[2]
    individualOffensivePlayerDataframe['League'] = league
    individualOffensivePlayerDataframe['Season'] = season
    for index, row in individualOffensivePlayerDataframe.iterrows():
        age = int(row["Age"]) - (2018-int(row["Season"]))
        individualOffensivePlayerDataframe.set_value(index, 'Age', age)
        
        #Cleaning Apps column
        if '(' in row["Apps"] :
            apps = int(row["Apps"].split("(")[0])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
        else :
            apps = int(row["Apps"])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
    
#     individualOffensivePlayerDataframe = individualOffensivePlayerDataframe.drop_duplicates(subset=['Name'], keep='first')
    li.append(individualOffensivePlayerDataframe)

combinedDefensivePlayerDataframe = pd.concat(li)
# Out:
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
#Combining All Passing Data
path = r'../Datasets/Whoscored/Player-Stats'
folder = glob.glob(path + "/*Passing*.csv")

li = []

for file in folder:
    individualOffensivePlayerDataframe = pd.read_csv(file)
    league = os.path.basename(file).split('-')[0]
    season = os.path.basename(file).split('-')[2]
    individualOffensivePlayerDataframe['League'] = league
    individualOffensivePlayerDataframe['Season'] = season
    for index, row in individualOffensivePlayerDataframe.iterrows():
        age = int(row["Age"]) - (2018-int(row["Season"]))
        individualOffensivePlayerDataframe.set_value(index, 'Age', age)
        
        #Cleaning Apps column
        if '(' in row["Apps"] :
            apps = int(row["Apps"].split("(")[0])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
        else :
            apps = int(row["Apps"])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
    
#     individualOffensivePlayerDataframe = individualOffensivePlayerDataframe.drop_duplicates(subset=['Name'], keep='first')
    li.append(individualOffensivePlayerDataframe)

combinedPassingPlayerDataframe = pd.concat(li)
# Out:
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
#Combining All Summary Data
path = r'../Datasets/Whoscored/Player-Stats'
folder = glob.glob(path + "/*Summary*.csv")

li = []

for file in folder:
    individualOffensivePlayerDataframe = pd.read_csv(file)
    league = os.path.basename(file).split('-')[0]
    season = os.path.basename(file).split('-')[2]
    individualOffensivePlayerDataframe['League'] = league
    individualOffensivePlayerDataframe['Season'] = season
    for index, row in individualOffensivePlayerDataframe.iterrows():
        age = int(row["Age"]) - (2018-int(row["Season"]))
        individualOffensivePlayerDataframe.set_value(index, 'Age', age)
        
        #Cleaning Apps column
        if '(' in row["Apps"] :
            apps = int(row["Apps"].split("(")[0])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
        else :
            apps = int(row["Apps"])
            individualOffensivePlayerDataframe.set_value(index, 'Apps', apps)
    
#     individualOffensivePlayerDataframe = individualOffensivePlayerDataframe.drop_duplicates(subset=['Name'], keep='first')
    li.append(individualOffensivePlayerDataframe)

combinedSummaryPlayerDataframe = pd.concat(li)
# Out:
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Suwadith\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
#combining all the DFs'

combinedPlayerDataframe = pd.concat([combinedOffensivePlayerDataframe, combinedDefensivePlayerDataframe, combinedPassingPlayerDataframe, combinedSummaryPlayerDataframe], axis=1)

combinedPlayerDataframe = combinedPlayerDataframe.loc[:,~combinedPlayerDataframe.columns.duplicated()]

#Removing all the goal keepers to test whether it improves the accuracy of the model.
combinedFieldPlayersDf = combinedPlayerDataframe[combinedPlayerDataframe.Position != 'GK']

#Removing field players who have played less than 10 matches
#combinedProperFieldPlayersDf = combinedFieldPlayersDf[~(combinedFieldPlayersDf['Apps'] < 8)]

# %%
combinedFieldPlayersDf
# Out:
#                       Name              Team  Age    Position Apps  Minutes  \
# 0             Arjen Robben     Bayern Munich   26   M(CLR),FW   18     1779
# 1          Stefan Kießling  Bayer Leverkusen   26          FW   33     2924
# 2       Zvjezdan Misimovic         Wolfsburg   28    AM(C),FW   31     2768
# 3               Edin Dzeko         Wolfsburg   24          FW   33     3003
# 4          Claudio Pizarro     Werder Bremen   31    AM(C),FW   23     2130
# ..                     ...               ...  ...         ...  ...      ...
# 565     Nicky Medja Beloko        Fiorentina   19  Midfielder    0       45
# 566        Stephy Mavididi          Juventus   21     Forward    0       21
# 567        Guido Guerrieri             Lazio   23  Goalkeeper    1       90
# 568        Carlo Pinsoglio          Juventus   29  Goalkeeper    1       90
# 569  Strahinja Tanasijevic            Chievo   22    Defender    1       18
#
#     Total goals Total Assists Shots per game Key passes per game  ...  \
# 0            16             6            3.4                 1.8  ...
# 1            21             5              3                 1.6  ...
# 2            10            13            2.4                 3.3  ...
# 3            22             7            4.5                 1.1  ...
# 4            16             2            2.6                 1.3  ...
# ..          ...           ...            ...                 ...  ...
# 565           -             -              -                   -  ...
# 566           -             -              -                   -  ...
# 567           -             -              -                   -  ...
# 568           -             -              -                   -  ...
# 569           -             -            0.5                   -  ...
#
#     Passes per game Pass success percentage Crosses per game  \
# 0              34.3                    80.2              1.5
# 1              32.5                    72.4              0.2
# 2              51.1                    77.5              2.5
# 3              19.5                    70.7              0.2
# 4              24.2                    75.5              0.1
# ..              ...                     ...              ...
# 565              10                      50                -
# 566               4                     100                -
# 567              27                    66.7                -
# 568              30                      70                -
# 569               7                    92.9                -
#
#     Long balls per game Through balls per game  Total Goals Yellow cards  \
# 0                     2                    0.2           16            1
# 1                   0.4                    0.1           21            3
# 2                   5.7                    0.5           10            7
# 3                   1.1                    0.1           22            4
# 4                   0.8                      -           16            4
# ..                  ...                    ...          ...          ...
# 565                   -                      -            -            1
# 566                   -                      -            -            -
# 567                   4                      -            -            -
# 568                   9                      -            -            -
# 569                   -                      -            -            1
#
#     Red cards Aerials won per game Man of the match
# 0           -                  0.4                8
# 1           -                  2.1                6
# 2           -                  0.2                8
# 3           -                  0.7                6
# 4           -                  0.4                2
# ..        ...                  ...              ...
# 565         -                    1                -
# 566         -                    -                -
# 567         -                    -                -
# 568         -                    -                -
# 569         1                    -                -
#
# [27918 rows x 35 columns]

# %%
combinedFieldPlayersDf.set_index(['Season']).sort_index()
# Out:
#                          Name           Team  Age       Position Apps  \
# Season
# 2009             Arjen Robben  Bayern Munich   26      M(CLR),FW   18
# 2009              Cesare Bovo        Palermo   27           D(C)   29
# 2009       Aleksandar Kolarov          Lazio   24     D(CL),M(L)   33
# 2009          John Arne Riise           Roma   29           D(L)   34
# 2009           Javier Zanetti          Inter   36  D(R),DMC,M(R)   37
# ...                       ...            ...  ...            ...  ...
# 2018        Guido Burgstaller     Schalke 04   30       AM(L),FW   17
# 2018       Yevhen Konoplyanka     Schalke 04   29      AM(CL),FW    7
# 2018              Felix Klaus      Wolfsburg   26        AM(CLR)    5
# 2018          Marvin Bakalorz    Hannover 96   29           M(C)   16
# 2018    Strahinja Tanasijevic         Chievo   22       Defender    1
#
#         Minutes Total goals Total Assists Shots per game Key passes per game  \
# Season
# 2009       1779          16             6            3.4                 1.8
# 2009       2610           2             1            0.7                 0.3
# 2009       2926           3             3              3                 1.1
# 2009       3083           5             -            2.2                 0.6
# 2009       3330           -             1            0.2                 0.6
# ...         ...         ...           ...            ...                 ...
# 2018       1524           4             -            1.8                 0.4
# 2018        654           1             -            1.3                 0.8
# 2018        438           1             1            1.1                 0.4
# 2018       1472           1             -            0.5                 0.3
# 2018         18           -             -            0.5                   -
#
#         ... Passes per game Pass success percentage Crosses per game  \
# Season  ...
# 2009    ...            34.3                    80.2              1.5
# 2009    ...            39.8                      77              0.3
# 2009    ...            36.4                    74.4              0.8
# 2009    ...            34.1                    78.9              0.5
# 2009    ...            46.9                    93.1              0.1
# ...     ...             ...                     ...              ...
# 2018    ...            11.9                    64.2              0.1
# 2018    ...            13.6                    79.1              0.5
# 2018    ...             8.8                    78.8              0.1
# 2018    ...            15.7                    75.8              0.1
# 2018    ...               7                    92.9                -
#
#        Long balls per game Through balls per game  Total Goals Yellow cards  \
# Season
# 2009                     2                    0.2           16            1
# 2009                   4.4                      -            2           12
# 2009                     2                    0.1            3            8
# 2009                   2.3                    0.1            5            4
# 2009                   2.1                      -            -            4
# ...                    ...                    ...          ...          ...
# 2018                   0.2                      -            4            4
# 2018                   0.5                      -            1            -
# 2018                   0.2                    0.1            1            -
# 2018                   0.5                      -            1            5
# 2018                     -                      -            -            1
#
#        Red cards Aerials won per game Man of the match
# Season
# 2009           -                  0.4                8
# 2009           -                  1.4                3
# 2009           1                  0.8                3
# 2009           -                    1                1
# 2009           -                  0.4                1
# ...          ...                  ...              ...
# 2018           -                  1.4                -
# 2018           1                  0.4                -
# 2018           -                  0.5                -
# 2018           -                  1.2                -
# 2018           1                    -                -
#
# [27918 rows x 34 columns]
